# %%
# !apt install texlive-fonts-recommended texlive-fonts-extra cm-super dvipng
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   cm-super-minimal dvisvgm fonts-adf-accanthis fonts-adf-berenis fonts-adf-gillius
#   fonts-adf-universalis fonts-cabin fonts-cantarell fonts-comfortaa fonts-croscore
#   fonts-crosextra-caladea fonts-crosextra-carlito fonts-dejavu-core fonts-dejavu-extra
#   fonts-droid-fallback fonts-ebgaramond fonts-ebgaramond-extra fonts-font-awesome
#   fonts-freefont-otf fonts-freefont-ttf fonts-gfs-artemisia fonts-gfs-complutum fonts-gfs-didot
#   fonts-gfs-neohellenic fonts-gfs-olga fonts-gfs-solomos fonts-go fonts-junicode fonts-lato
#   fonts-linuxlibertine fonts-lmodern fonts-lobster fonts-lobstertwo fonts-noto-color-emoji
#   fonts-noto-core fonts-noto-mono fonts-oflb-asana-math fonts-open-sans fonts-roboto-unhinted
#   fonts-sil-charis fonts-sil-gentium fonts-sil-gentium-basic fonts-sil-gentiumplus
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import pickle

# %%
params = {'text.usetex' : True,
          'font.size' : 11,
          'lines.markersize': 2,
          'lines.linewidth':1,
          'axes.labelpad': 1,
          'axes.labelpad': 1,
          'axes.facecolor': 'white'
          }

plt.rc('text.latex', preamble=r'\usepackage{amsfonts}')

plt.rcParams.update(params)

# %%
from google.colab import drive
drive.mount('/content/gdrive') # connect colab to your google drive. Before this, you would like to upload the files on your google drive
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
pth='/content/...' # create your own path

# %%
# you may want to change the directory as well
file_3=pth+'/E_n_N/Dict/Data_E_h_0.1_a_1_L13_mu_-0.4_500_T_10.0_S_40_Y_1.npz'
file_1=pth+'/E_n_N/Dict/Data_E_h_0.1_a_1_L13_mu_-0.4_500_T_10.0_S_40_Y_Z_1.npz'
file_2=pth+'/E_n_N/Dict/Data_E_h_0.1_a_1_L13_mu_-0.4_500_T_10.0_S_40_X_1.npz'
file_4=pth+'/E_n_N/Dict/Data_E_h_0.1_a_1_L13_mu_-0.4_500_T_10.0_S_40_X_Z_1.npz'

E4=np.load(file_4)
E3=np.load(file_3)
E2=np.load(file_2)
E1=np.load(file_1)

# %%
E_avg=[]
E1_avg=[]
E2_avg=[]
E3_avg=[]
for i in range(1,101):
    E_lst=[]
    E1_lst=[]
    E2_lst=[]
    E3_lst=[]
    for j in range(1,41):
        E_lst.append(np.mean(E3[str(i)][:j]))
        E1_lst.append(np.mean(E1[str(i)][:j]))
        E2_lst.append(np.mean(E2[str(i)][:j]))
        E3_lst.append(np.mean(E4[str(i)][:j]))

    E_avg.append(np.array(E_lst))#/100
    E1_avg.append(np.array(E1_lst))
    E2_avg.append(np.array(E2_lst))
    E3_avg.append(np.array(E3_lst))
E_avg=np.array(E_avg)
E1_avg=np.array(E1_avg)
E2_avg=np.array(E2_avg)
E3_avg=np.array(E3_avg)

stp_lst=[]
for i in range(1,41):
    stp_lst.append(i)

# %%
E_disb=[]
E1_disb=[]
E2_disb=[]
E3_disb=[]
for i in range(1,101):
    E_disb=E_disb+list(E3[str(i)]/12)
    E1_disb=E1_disb+list(E1[str(i)]/12)
    E2_disb=E2_disb+list(E2[str(i)]/12)
    E3_disb=E3_disb+list(E4[str(i)]/12)

# %%
# you may want to change the directory as well
file_3=pth+'/E_n_N/Dict/Data_N_h_0.1_a_1_L13_mu_-0.4_500_T_10.0_S_40_Y_1.npz'
file_1=pth+'/E_n_N/Dict/Data_N_h_0.1_a_1_L13_mu_-0.4_500_T_10.0_S_40_Y_Z_1.npz'
file_2=pth+'/E_n_N/Dict/Data_N_h_0.1_a_1_L13_mu_-0.4_500_T_10.0_S_40_X_1.npz'
file_4=pth+'/E_n_N/Dict/Data_N_h_0.1_a_1_L13_mu_-0.4_500_T_10.0_S_40_X_Z_1.npz'

# %%
N4=np.load(file_4)
N3=np.load(file_3)
N2=np.load(file_2)
N1=np.load(file_1)

# %%
N_avg=[]
N1_avg=[]
N2_avg=[]
N3_avg=[]
for i in range(1,101):
    N_lst=[]
    N1_lst=[]
    N2_lst=[]
    N3_lst=[]
    for j in range(1,41):
        N_lst.append(np.mean(N3[str(i)][:j]))
        N1_lst.append(np.mean(N1[str(i)][:j]))
        N2_lst.append(np.mean(N2[str(i)][:j]))
        N3_lst.append(np.mean(N4[str(i)][:j]))

    N_avg.append(np.array(N_lst))#/100
    N1_avg.append(np.array(N1_lst))
    N2_avg.append(np.array(N2_lst))
    N3_avg.append(np.array(N3_lst))
N_avg=np.array(N_avg)
N1_avg=np.array(N1_avg)
N2_avg=np.array(N2_avg)
N3_avg=np.array(N3_avg)

# %%
N_disb=[]
N1_disb=[]
N2_disb=[]
N3_disb=[]
for i in range(1,101):
    N_disb=N_disb+list(N3[str(i)]/12+0.5)
    N1_disb=N1_disb+list(N1[str(i)]/12+0.5)
    N2_disb=N2_disb+list(N2[str(i)]/12+0.5)
    N3_disb=N3_disb+list(N4[str(i)]/12+0.5)

stp_lst=[]
for i in range(1,41):
    stp_lst.append(i)

# %%
fig,axes = plt.subplots(2,2,sharex = False,sharey = False, figsize = (1.35*3.375,1.35*0.85*3.375),squeeze = False)#,width_ratios=[1,1.04])
plt.subplots_adjust(hspace=0.3,wspace=0.3)


axes[0,0].errorbar(stp_lst, np.mean(E2_avg, axis=0)/12, yerr=np.std(E2_avg, axis=0)/12/10,c='b',capsize=1,label='X')
axes[0,0].errorbar(stp_lst, np.mean(E_avg, axis=0)/12, yerr=np.std(E_avg, axis=0)/12/10,c='c',capsize=1,label='Y')
axes[0,0].errorbar(stp_lst, np.mean(E3_avg, axis=0)/12, yerr=np.std(E3_avg, axis=0)/12/10,c='k',capsize=1,label='X-Z')
axes[0,0].errorbar(stp_lst, np.mean(E1_avg, axis=0)/12, yerr=np.std(E1_avg, axis=0)/12/10,c='m',capsize=1,label='Y-Z')
axes[0,0].axhline(-0.2663423278727075,c='r',label='exact') #-0.8740685315283336 0.8 #-0.20656808762930012 -0.65 -0.8401904474148425
axes[0,0].set_ylabel(r'$\left\langle \epsilon\right\rangle $')
axes[0,0].yaxis.set_label_coords(-0.1,0.5)
axes[0,0].text(0.02,1.05,r"$\mathrm{(a)}$",transform=axes[0,0].transAxes)
axes[0,0].set_yticks([-0.27,-0.26])

axes[0,1].errorbar(stp_lst, np.mean(N2_avg, axis=0)/12+0.5, yerr=np.std(N2_avg, axis=0)/12/10,c='b',capsize=1,label='X')
axes[0,1].errorbar(stp_lst, np.mean(N_avg, axis=0)/12+0.5, yerr=np.std(N_avg, axis=0)/12/10,c='c',capsize=1,label='Y')
axes[0,1].errorbar(stp_lst, np.mean(N3_avg, axis=0)/12+0.5, yerr=np.std(N3_avg, axis=0)/12/10,c='k',capsize=1,label='X-Z')
axes[0,1].errorbar(stp_lst, np.mean(N1_avg, axis=0)/12+0.5, yerr=np.std(N1_avg, axis=0)/12/10,c='m',capsize=1,label='Y-Z')

axes[0,1].axhline(0.3061365219783673,c='r',label='exact') #0.2469623424146813  0.2553683261498189 0.2958010896895695
axes[0,1].set_ylabel(r'$\left\langle n\right\rangle $')
axes[0,1].yaxis.set_label_coords(-0.1,0.5)

axes[0,1].set_ylim(0.291,0.309)
axes[0,1].set_yticks([0.295,0.305])


axes[0,1].legend(bbox_to_anchor=(1.05, 0.3),loc='center right',frameon=False,labelspacing = 0.09,handlelength=0.7)
axes[0,1].text(0.02,1.05,r"$\mathrm{(b)}$",transform=axes[0,1].transAxes)

axes[1,0].errorbar(stp_lst, np.abs(np.mean(E2_avg, axis=0)/12+0.2663423278727075)/0.2663423278727075,c='b',label='X')
axes[1,0].errorbar(stp_lst, np.abs(np.mean(E_avg, axis=0)/12+0.2663423278727075)/0.2663423278727075, c='c',label='Y')
axes[1,0].errorbar(stp_lst, np.abs(np.mean(E3_avg, axis=0)/12+0.2663423278727075)/0.2663423278727075, c='k',label='X-Z')
axes[1,0].errorbar(stp_lst, np.abs(np.mean(E1_avg, axis=0)/12+0.2663423278727075)/0.2663423278727075, c='m',label='Y-Z')
axes[1,0].set_yscale('log')

axes[1,0].set_ylabel(r"$\Delta_\epsilon$")

axes[1,0].set_xlabel(r"$\mathrm{Thermal}$ $\mathrm{step}$")
axes[1,0].yaxis.set_label_coords(-0.1,0.5)
axes[1,0].text(0.02,1.05,r"$\mathrm{(c)}$",transform=axes[1,0].transAxes)
axes[1,0].set_ylim(5e-6,3e-2)


axes[1,1].plot(stp_lst, np.abs(np.mean(N2_avg, axis=0)/12+0.5-0.3061365219783673)/0.3061365219783673,c='b',label='X')
axes[1,1].plot(stp_lst, np.abs(np.mean(N_avg, axis=0)/12+0.5-0.3061365219783673)/0.3061365219783673,c='c',label='Y')
axes[1,1].plot(stp_lst, np.abs(np.mean(N3_avg, axis=0)/12+0.5-0.3061365219783673)/0.3061365219783673,c='k',label='X-Z')
axes[1,1].plot(stp_lst, np.abs(np.mean(N1_avg, axis=0)/12+0.5-0.3061365219783673)/0.3061365219783673,c='m',label='Y-Z')

axes[1,1].yaxis.set_label_coords(-0.1,0.5)
axes[1,1].set_yscale('log')
axes[1,1].set_ylim(5e-6,3e-2)

axes[1,1].set_ylabel(r"$\Delta_n$")
axes[1,1].set_xlabel(r"$\mathrm{Thermal}$ $\mathrm{step}$")
axes[1,1].text(0.02,1.05,r"$\mathrm{(d)}$",transform=axes[1,1].transAxes)
plt.savefig("E_n_N.png",dpi = 300,bbox_inches='tight',facecolor='white',transparent=False)

# %%
Nc_T_dict_avg_c={}
Nc_T_dict_std_c={}
beta_lst=[5.0,10.0,20.0,30.0,40.0,50.0]
for beta in beta_lst:
    file_ni=pth+'/E_n_N/Dict/Data_Ni_h_0.0_a_1_L13_mu_-0.55_500_T_'+str(beta)+'_S_20_Y_Z_1.npz'
    Ni=np.load(file_ni)
    Nc_T_dict_avg_c[beta]=[]
    Nc_T_dict_std_c[beta]=[]
    for site in range(12):
        Nc_T_dict_avg_c[beta].append(np.mean(Ni[site]))
        Nc_T_dict_std_c[beta].append(np.std(Ni[site]))

Nc_T_dict_avg_n={}
Nc_T_dict_std_n={}
beta_lst=[5.0,10.0,20.0,30.0,40.0,50.0]
for beta in beta_lst:
    file_ni=pth+'/E_n_N/Dict/Data_Ni_h_0.1_a_1_L13_mu_-0.4_500_T_'+str(beta)+'_S_20_Y_Z_1.npz'
    Ni=np.load(file_ni)
    Nc_T_dict_avg_n[beta]=[]
    Nc_T_dict_std_n[beta]=[]
    for site in range(12):
        Nc_T_dict_avg_n[beta].append(np.mean(Ni[site]))
        Nc_T_dict_std_n[beta].append(np.std(Ni[site]))

# %%
Site=[i for i in range(1,13)]
colors=['c','m','b','k','r']

# %%
fig,axes = plt.subplots(2,2,sharex = False,sharey = False, figsize = (1.35*3.375,1.35*0.85*3.375),squeeze = False)
plt.subplots_adjust(hspace=0.1,wspace=0.05)

beta_lst=[5.0,10.0,20.0]#,30.0,40.0,50.0]

Site=[i for i in range(1,13)]
colors=['c','m','b','k','r']

for i,beta in enumerate(beta_lst):
    axes[0,0].errorbar(Site,np.array(Nc_T_dict_avg_c[beta])+0.5,c=colors[i],yerr=np.array(Nc_T_dict_std_c[beta])/10)#,label=r"$\beta=$"+str(beta))

for beta in beta_lst:
    file_ni=pth+'/E_n_N/Ext/NC_Ni_'+str(int(beta))+'.npy'
    Ni=np.load(file_ni)
    axes[0,0].plot(Site,Ni,'--',label=r"Exact $\beta=$"+str(beta))

axes[0,0].set_ylim(0.14,0.4)
axes[0,0].legend(bbox_to_anchor=(0.5, -0.045),frameon=False,loc=8,labelspacing = 0.07,handlelength=1)
axes[0,0].set_ylabel(r'$\left(N_{i}\right)_{\mu,\beta}$')
axes[0,0].text(0.02,0.92,r"$\mathrm{(a)}$",transform=axes[0,0].transAxes)
axes[0,0].set_xticks([])
axes[1,0].set_xlabel(r'$\mathrm{Site} $')

Site=[i for i in range(1,13)]
colors=['c','m','b','k','r']

for i,beta in enumerate(beta_lst):
    axes[1,0].errorbar(Site,np.array(Nc_T_dict_avg_n[beta])+0.5,c=colors[i],yerr=np.array(Nc_T_dict_std_n[beta])/10)

for beta in beta_lst:
    file_ni=pth+'/E_n_N/Ext/C_Ni_'+str(int(beta))+'.npy'
    Ni=np.load(file_ni)
    axes[1,0].plot(Site,Ni,'--')

axes[1,0].text(0.02,0.92,r"$\mathrm{(b)}$",transform=axes[1,0].transAxes)
axes[1,0].set_ylabel(r'$\left(N_{i}\right)_{\mu,\beta}$')
axes[1,0].set_ylim(0.1,0.44)
axes[1,0].set_xticks(Site)

Nc_T_dict_avg_c={}
Nc_T_dict_std_c={}
#beta_lst=[10.0,20.0,30.0,40.0,50.0]
for beta in beta_lst:
    file_ni=pth+'/E_n_N/Dict/L60/Data_Ni_h_0.0_a_1_L61_mu_-0.55_500_T_'+str(beta)+'_S_20_Y_Z_1.npz'
    Ni=np.load(file_ni)
    Nc_T_dict_avg_c[beta]=[]
    Nc_T_dict_std_c[beta]=[]
    for site in range(60):
        Nc_T_dict_avg_c[beta].append(np.mean(Ni[site]))
        Nc_T_dict_std_c[beta].append(np.std(Ni[site]))

Nc_T_dict_avg_n={}
Nc_T_dict_std_n={}
#beta_lst=[10.0,20.0,30.0,40.0,50.0]
for beta in beta_lst:
    file_ni=pth+'/E_n_N/Dict/L60/Data_Ni_h_0.1_a_1_L61_mu_-0.4_500_T_'+str(beta)+'_S_20_Y_Z_1.npz'
    Ni=np.load(file_ni)
    Nc_T_dict_avg_n[beta]=[]
    Nc_T_dict_std_n[beta]=[]
    for site in range(60):
        Nc_T_dict_avg_n[beta].append(np.mean(Ni[site]))
        Nc_T_dict_std_n[beta].append(np.std(Ni[site]))


Site=[i for i in range(1,61)]
colors=['c','m','b','k','r']

for i,beta in enumerate(beta_lst):
    axes[0,1].errorbar(Site,np.array(Nc_T_dict_avg_c[beta])+0.5,c=colors[i],yerr=np.array(Nc_T_dict_std_c[beta])/10,label=r"$\beta=$"+str(beta))


axes[0,1].set_ylim(0.14,0.4)
axes[0,1].legend(bbox_to_anchor=(0.5, -0.045),frameon=False,loc=8,labelspacing = 0.07,handlelength=1)
#axes[0,1].set_ylabel(r'$\left(n_{i}\right)_{\mu,\beta}$')
axes[0,1].text(0.02,0.92,r"$\mathrm{(c)}$",transform=axes[0,1].transAxes)

axes[0,1].set_yticks([])
axes[0,1].set_xticks([])

axes[1,1].set_xlabel(r'$\mathrm{Site} $')

#Site=[i for i in range(1,13)]
colors=['c','m','b','k','r']

for i,beta in enumerate(beta_lst):
    axes[1,1].errorbar(Site,np.array(Nc_T_dict_avg_n[beta])+0.5,c=colors[i],yerr=np.array(Nc_T_dict_std_n[beta])/10)



axes[1,1].text(0.02,0.92,r"$\mathrm{(d)}$",transform=axes[1,1].transAxes)
axes[1,1].set_ylim(0.1,0.44)
axes[1,1].set_yticks([])
#axes[1,1].set_ylabel(r'$\left(n_{i}\right)_{\mu,\beta}$')
#axes[1,0].set_xticks(Site)
plt.savefig("FO.png",dpi = 300,bbox_inches='tight',facecolor='white',transparent=False)

# %%
N=37
cutoff=1E-9
δτ=0.05
beta=10.0
NMETTS=50
Nwarm=10

hz_edge=0.1
hz=hz_edge#parse(Float64, ARGS[2])
m=0.0
mu=-0.4
a=1

b = np.load(pth+"/E_n_N/Strength_length/Ant_St_Disb_h_"+str(hz)+"_a_"+str(a)+"_L"+str(N)+"_mu_"+str(mu)+"_500_T_"+str(beta)+"_S_"+str(NMETTS)+".npz")
a = np.load(pth+"/E_n_N/Strength_length/St_Disb_h_"+str(hz)+"_a_"+str(a)+"_L"+str(N)+"_mu_"+str(mu)+"_500_T_"+str(beta)+"_S_"+str(NMETTS)+".npz")

dict_ans_c_10={}

for i in range(1,N):
    dict_ans_c_10[i-0.2]=b[str(i)]/2000/50

dict_s_c_10={}

for i in range(1,N):
    dict_s_c_10[i+0.2]=a[str(i)]/2000/50

N=37
cutoff=1E-9
δτ=0.05
beta=10.0
NMETTS=50
Nwarm=10

hz_edge=0.0
hz=hz_edge#parse(Float64, ARGS[2])
m=0.0
mu=-0.55
a=1

b = np.load(pth+"/E_n_N/Strength_length/Ant_St_Disb_h_"+str(hz)+"_a_"+str(a)+"_L"+str(N)+"_mu_"+str(mu)+"_500_T_"+str(beta)+"_S_"+str(NMETTS)+".npz")
a = np.load(pth+"/E_n_N/Strength_length/St_Disb_h_"+str(hz)+"_a_"+str(a)+"_L"+str(N)+"_mu_"+str(mu)+"_500_T_"+str(beta)+"_S_"+str(NMETTS)+".npz")

dict_ans_f_10={}

for i in range(1,N):
    dict_ans_f_10[i-0.2]=b[str(i)]/2000/50

dict_s_f_10={}

for i in range(1,N):
    dict_s_f_10[i+0.2]=a[str(i)]/2000/50

beta=20.0

hz_edge=0.1
hz=hz_edge#parse(Float64, ARGS[2])
mu=-0.4
a=1

b = np.load(pth+"/E_n_N/Strength_length/Ant_St_Disb_h_"+str(hz)+"_a_"+str(a)+"_L"+str(N)+"_mu_"+str(mu)+"_500_T_"+str(beta)+"_S_"+str(NMETTS)+".npz")
a = np.load(pth+"/E_n_N/Strength_length/St_Disb_h_"+str(hz)+"_a_"+str(a)+"_L"+str(N)+"_mu_"+str(mu)+"_500_T_"+str(beta)+"_S_"+str(NMETTS)+".npz")

dict_ans_c_20={}
for i in range(1,N):
    dict_ans_c_20[i-0.2]=b[str(i)]/2000/50

dict_s_c_20={}
for i in range(1,N):
    dict_s_c_20[i+0.2]=a[str(i)]/2000/50

beta=20.0

hz_edge=0.0
hz=hz_edge#parse(Float64, ARGS[2])
mu=-0.55
a=1

b = np.load(pth+"/E_n_N/Strength_length/Ant_St_Disb_h_"+str(hz)+"_a_"+str(a)+"_L"+str(N)+"_mu_"+str(mu)+"_500_T_"+str(beta)+"_S_"+str(NMETTS)+".npz")
a = np.load(pth+"/E_n_N/Strength_length/St_Disb_h_"+str(hz)+"_a_"+str(a)+"_L"+str(N)+"_mu_"+str(mu)+"_500_T_"+str(beta)+"_S_"+str(NMETTS)+".npz")

dict_ans_f_20={}
for i in range(1,N):
    dict_ans_f_20[i-0.2]=b[str(i)]/2000/50

dict_s_f_20={}
for i in range(1,N):
    dict_s_f_20[i+0.2]=a[str(i)]/2000/50

beta=5.0

hz_edge=0.1
hz=hz_edge#parse(Float64, ARGS[2])
mu=-0.4
a=1

b = np.load(pth+"/E_n_N/Strength_length/Ant_St_Disb_h_"+str(hz)+"_a_"+str(a)+"_L"+str(N)+"_mu_"+str(mu)+"_500_T_"+str(beta)+"_S_"+str(NMETTS)+".npz")
a = np.load(pth+"/E_n_N/Strength_length/St_Disb_h_"+str(hz)+"_a_"+str(a)+"_L"+str(N)+"_mu_"+str(mu)+"_500_T_"+str(beta)+"_S_"+str(NMETTS)+".npz")

dict_ans_c_5={}
for i in range(1,N):
    dict_ans_c_5[i-0.2]=b[str(i)]/2000/50

dict_s_c_5={}
for i in range(1,N):
    dict_s_c_5[i+0.2]=a[str(i)]/2000/50

beta=5.0

hz_edge=0.0
hz=hz_edge#parse(Float64, ARGS[2])
mu=-0.55
a=1

b = np.load(pth+"/E_n_N/Strength_length/Ant_St_Disb_h_"+str(hz)+"_a_"+str(a)+"_L"+str(N)+"_mu_"+str(mu)+"_500_T_"+str(beta)+"_S_"+str(NMETTS)+".npz")
a = np.load(pth+"/E_n_N/Strength_length/St_Disb_h_"+str(hz)+"_a_"+str(a)+"_L"+str(N)+"_mu_"+str(mu)+"_500_T_"+str(beta)+"_S_"+str(NMETTS)+".npz")

dict_ans_f_5={}
for i in range(1,N):
    dict_ans_f_5[i-0.2]=b[str(i)]/2000/50

dict_s_f_5={}
for i in range(1,N):
    dict_s_f_5[i+0.2]=a[str(i)]/2000/50

# %%
width = 0.4

# %%
fig,axes = plt.subplots(2,3,sharex = True,sharey = False, figsize = (2*1.35*3.375,1.3*1.35*0.85*3.375),squeeze = False)#,width_ratios=[1,1.04])
plt.subplots_adjust(hspace=0.05,wspace=0.2)

#axes[0,0].grid()

axes[0,0].bar(dict_ans_c_20.keys(), dict_ans_c_20.values(), width, color='b',label='Ant-string')
axes[0,0].bar(dict_s_c_20.keys(), dict_s_c_20.values(), width, color='orange',label='string')
axes[0,0].set_xlim(0,15)
axes[0,0].text(0.5,0.7,r"$\beta=20$",transform=axes[0,0].transAxes)


axes[0,1].bar(dict_ans_c_10.keys(), dict_ans_c_10.values(), width, color='b',label='Ant-string')
axes[0,1].bar(dict_s_c_10.keys(), dict_s_c_10.values(), width, color='orange',label='string')
axes[0,1].text(0.5,0.7,r"$\beta=10$",transform=axes[0,1].transAxes)


axes[0,2].bar(dict_ans_c_5.keys(), dict_ans_c_5.values(), width, color='b',label='Ant-string')
axes[0,2].bar(dict_s_c_5.keys(), dict_s_c_5.values(), width, color='orange',label='string')
axes[0,2].text(0.5,0.7,r"$\beta=5$",transform=axes[0,2].transAxes)

axes[1,0].bar(dict_ans_f_20.keys(), dict_ans_f_20.values(), width, color='b',label='Ant-string')
axes[1,0].bar(dict_s_f_20.keys(), dict_s_f_20.values(), width, color='orange',label='string')
axes[1,0].text(0.5,0.7,r"$\beta=20$",transform=axes[1,0].transAxes)
axes[1,0].set_xlabel(r"$\mathrm{Length}$")

axes[1,1].bar(dict_ans_f_10.keys(), dict_ans_f_10.values(), width, color='b',label='Ant-string')
axes[1,1].bar(dict_s_f_10.keys(), dict_s_f_10.values(), width, color='orange',label='string')
axes[1,1].text(0.5,0.7,r"$\beta=10$",transform=axes[1,1].transAxes)
axes[1,1].set_xlabel(r"$\mathrm{Length}$")

axes[1,2].bar(dict_ans_f_5.keys(), dict_ans_f_5.values(), width, color='b',label='Ant-string')
axes[1,2].bar(dict_s_f_5.keys(), dict_s_f_5.values(), width, color='orange',label='string')
axes[1,2].text(0.5,0.7,r"$\beta=5$",transform=axes[1,2].transAxes)
axes[1,2].set_xlabel(r"$\mathrm{Length}$")



plt.savefig("SL.png",dpi = 300,bbox_inches='tight',facecolor='white',transparent=False)

# %%
E_mu_lst=[]
E_mu_std=[]
N_mu_lst=[]
N_mu_std=[]
for i in range(51):
    mu=-1.0+i*0.04
    mu=np.round(mu,2)
    file_ni=pth+'/E_n_N/h00_b10/Data_E_h_0.0_a_1_L61_mu_'+str(mu)+'_500_T_10.0_S_20_Y_Z_'+str(i)+'.npz'
    file_n=pth+'/E_n_N/h00_b10/Data_N_h_0.0_a_1_L61_mu_'+str(mu)+'_500_T_10.0_S_20_Y_Z_'+str(i)+'.npz'
    Ni=np.load(file_ni)
    N=np.load(file_n)
    E_lst=[]
    N_lst=[]
    for j in range(1,101):
        E_lst.append(np.mean(Ni[str(j)]))
        N_lst.append(np.mean(N[str(j)]))
    E_mu_lst.append(np.mean(E_lst)/60)
    E_mu_std.append(np.std(E_lst)/10/60)
    N_mu_lst.append(np.mean(N_lst)/60)
    N_mu_std.append(np.std(N_lst)/10/60)

# %%
fig,axes = plt.subplots(1,2,sharex = False,sharey = True, figsize = (2*1.35*3.375,2*1.35*0.85*3.375/2),squeeze = False)
plt.subplots_adjust(wspace=0.05)

E_mu_lst=[]
E_mu_std=[]
N_mu_lst=[]
N_mu_std=[]
for i in range(51):
    mu=-1.0+i*0.04
    mu=np.round(mu,2)
    file_ni=pth+'/E_n_N/h00_b20/Data_E_h_0.0_a_1_L61_mu_'+str(mu)+'_500_T_20.0_S_20_Y_Z_'+str(i)+'.npz'
    file_n=pth+'/E_n_N/h00_b20/Data_N_h_0.0_a_1_L61_mu_'+str(mu)+'_500_T_20.0_S_20_Y_Z_'+str(i)+'.npz'
    Ni=np.load(file_ni)
    N=np.load(file_n)
    E_lst=[]
    N_lst=[]
    for j in range(1,101):
        E_lst.append(np.mean(Ni[str(j)]))
        N_lst.append(np.mean(N[str(j)]))
    E_mu_lst.append(np.mean(E_lst)/60)
    E_mu_std.append(np.std(E_lst)/10/60)
    N_mu_lst.append(0.5+np.mean(N_lst)/60)
    N_mu_std.append(np.std(N_lst)/10/60)
analy=np.load(pth+"/E_n_N/analytical_infinite_beta_20.npy")
axes[0,0].plot(analy[:,0], analy[:,1],c='k', linestyle='dashed',label=r'$\beta=20$')
axes[0,0].set_ylabel(r'$\left\langle \epsilon\right\rangle_{\mu,\beta}$')
axes[0,0].errorbar(N_mu_lst,E_mu_lst, yerr=E_mu_std, xerr=N_mu_std)
axes[0,0].set_xlabel(r'$\left\langle n\right\rangle_{\mu,\beta}$')

E_mu_lst=[]
E_mu_std=[]
N_mu_lst=[]
N_mu_std=[]
for i in range(51):
    mu=-1.0+i*0.04
    mu=np.round(mu,2)
    file_ni=pth+'/E_n_N/h00_b10/Data_E_h_0.0_a_1_L61_mu_'+str(mu)+'_500_T_10.0_S_20_Y_Z_'+str(i)+'.npz'
    file_n=pth+'/E_n_N/h00_b10/Data_N_h_0.0_a_1_L61_mu_'+str(mu)+'_500_T_10.0_S_20_Y_Z_'+str(i)+'.npz'
    Ni=np.load(file_ni)
    N=np.load(file_n)
    E_lst=[]
    N_lst=[]
    for j in range(1,101):
        E_lst.append(np.mean(Ni[str(j)]))
        N_lst.append(np.mean(N[str(j)]))
    E_mu_lst.append(np.mean(E_lst)/60)
    E_mu_std.append(np.std(E_lst)/10/60)
    N_mu_lst.append(0.5+np.mean(N_lst)/60)
    N_mu_std.append(np.std(N_lst)/10/60)

analy=np.load(pth+"/E_n_N/analytical_infinite_beta_10.npy")
axes[0,0].plot(analy[:,0], analy[:,1],c='r', linestyle='dashed',label=r'$\beta=10$')
axes[0,0].set_ylabel(r'$\left\langle \epsilon\right\rangle_{\mu,\beta}$')
axes[0,0].errorbar(N_mu_lst,E_mu_lst, yerr=E_mu_std, xerr=N_mu_std)
axes[0,0].set_xlabel(r'$\left\langle n\right\rangle_{\mu,\beta}$')

E_mu_lst=[]
E_mu_std=[]
N_mu_lst=[]
N_mu_std=[]
for i in range(51):
    mu=-1.0+i*0.04
    mu=np.round(mu,2)
    file_ni=pth+'/E_n_N/h00_b5/Data_E_h_0.0_a_1_L61_mu_'+str(mu)+'_500_T_5.0_S_20_Y_Z_'+str(i)+'.npz'
    file_n=pth+'/E_n_N/h00_b5/Data_N_h_0.0_a_1_L61_mu_'+str(mu)+'_500_T_5.0_S_20_Y_Z_'+str(i)+'.npz'
    Ni=np.load(file_ni)
    N=np.load(file_n)
    E_lst=[]
    N_lst=[]
    for j in range(1,101):
        E_lst.append(np.mean(Ni[str(j)]))
        N_lst.append(np.mean(N[str(j)]))
    E_mu_lst.append(np.mean(E_lst)/60)
    E_mu_std.append(np.std(E_lst)/10/60)
    N_mu_lst.append(0.5+np.mean(N_lst)/60)
    N_mu_std.append(np.std(N_lst)/10/60)
analy=np.load(pth+"/E_n_N/analytical_infinite_beta_5.npy")
axes[0,0].plot(analy[:,0], analy[:,1],c='b', linestyle='dashed',label=r'$\beta=5$')
axes[0,0].text(0.06,0.92,r"$\mathrm{(a)}$",transform=axes[0,0].transAxes)
axes[0,0].errorbar(N_mu_lst,E_mu_lst, yerr=E_mu_std, xerr=N_mu_std)

E_mu_lst=[]
E_mu_std=[]
N_mu_lst=[]
N_mu_std=[]
for i in range(51):
    mu=-1.0+i*0.04
    mu=np.round(mu,2)
    file_ni=pth+'/E_n_N/h01_b20/Data_E_h_0.1_a_1_L61_mu_'+str(mu)+'_500_T_20.0_S_20_Y_Z_'+str(i)+'.npz'
    file_n=pth+'/E_n_N/h01_b20/Data_N_h_0.1_a_1_L61_mu_'+str(mu)+'_500_T_20.0_S_20_Y_Z_'+str(i)+'.npz'
    Ni=np.load(file_ni)
    N=np.load(file_n)
    E_lst=[]
    N_lst=[]
    for j in range(1,101):
        E_lst.append(np.mean(Ni[str(j)]))
        N_lst.append(np.mean(N[str(j)]))
    E_mu_lst.append(np.mean(E_lst)/60)
    E_mu_std.append(np.std(E_lst)/10/60)
    N_mu_lst.append(0.5+np.mean(N_lst)/60)
    N_mu_std.append(np.std(N_lst)/10/60)

#axes[0,1].set_xlabel(r'$\left\langle n\right\rangle_{\mu,\beta}$')
axes[0,1].errorbar(N_mu_lst,E_mu_lst, yerr=E_mu_std, xerr=N_mu_std,label=r'$\beta=20$')

axes[0,0].legend(frameon=False,labelspacing = 0.07,handlelength=1)
plt.savefig("E_n.png",dpi = 300,bbox_inches='tight',facecolor='white',transparent=False)

E_mu_lst=[]
E_mu_std=[]
N_mu_lst=[]
N_mu_std=[]
for i in range(51):
    mu=-1.0+i*0.04
    mu=np.round(mu,2)
    file_ni=pth+'/E_n_N/h01_b10/Data_E_h_0.1_a_1_L61_mu_'+str(mu)+'_500_T_10.0_S_20_Y_Z_'+str(i)+'.npz'
    file_n=pth+'/E_n_N/h01_b10/Data_N_h_0.1_a_1_L61_mu_'+str(mu)+'_500_T_10.0_S_20_Y_Z_'+str(i)+'.npz'
    Ni=np.load(file_ni)
    N=np.load(file_n)
    E_lst=[]
    N_lst=[]
    for j in range(1,101):
        E_lst.append(np.mean(Ni[str(j)]))
        N_lst.append(np.mean(N[str(j)]))
    E_mu_lst.append(np.mean(E_lst)/60)
    E_mu_std.append(np.std(E_lst)/10/60)
    N_mu_lst.append(0.5+np.mean(N_lst)/60)
    N_mu_std.append(np.std(N_lst)/10/60)

axes[0,1].set_xlabel(r'$\left\langle n\right\rangle_{\mu,\beta}$')
axes[0,1].errorbar(N_mu_lst,E_mu_lst, yerr=E_mu_std, xerr=N_mu_std,label=r'$\beta=10$')

E_mu_lst=[]
E_mu_std=[]
N_mu_lst=[]
N_mu_std=[]
for i in range(51):
    mu=-1.0+i*0.04
    mu=np.round(mu,2)
    file_ni=pth+'/E_n_N/h01_b5/Data_E_h_0.1_a_1_L61_mu_'+str(mu)+'_500_T_5.0_S_20_Y_Z_'+str(i)+'.npz'
    file_n=pth+'/E_n_N/h01_b5/Data_N_h_0.1_a_1_L61_mu_'+str(mu)+'_500_T_5.0_S_20_Y_Z_'+str(i)+'.npz'
    Ni=np.load(file_ni)
    N=np.load(file_n)
    E_lst=[]
    N_lst=[]
    for j in range(1,101):
        E_lst.append(np.mean(Ni[str(j)]))
        N_lst.append(np.mean(N[str(j)]))
    E_mu_lst.append(np.mean(E_lst)/60)
    E_mu_std.append(np.std(E_lst)/10/60)
    N_mu_lst.append(0.5+np.mean(N_lst)/60)
    N_mu_std.append(np.std(N_lst)/10/60)

#axes[0,1].set_xlabel(r'$\left\langle n\right\rangle_{\mu,\beta}$')
axes[0,1].text(0.06,0.92,r"$\mathrm{(b)}$",transform=axes[0,1].transAxes)
axes[0,1].errorbar(N_mu_lst,E_mu_lst, yerr=E_mu_std, xerr=N_mu_std,label=r'$\beta=5$')

axes[0,1].legend(frameon=False,labelspacing = 0.07,handlelength=1)
plt.savefig("E_n.png",dpi = 300,bbox_inches='tight',facecolor='white',transparent=False)

# %%
beta=5

# %%
a = np.load(pth+"/E_n_N/analytical_infinite_beta_"+str(beta)+".npy")

# %%
a[:,1]
# Out:
# array([-0.09674752, -0.0973377 , -0.0979294 , -0.09852261, -0.0991173 ,
#        -0.09971347, -0.10031109, -0.10091014, -0.10151061, -0.10211248,
#        -0.10271572, -0.10332032, -0.10392626, -0.10453351, -0.10514207,
#        -0.1057519 , -0.106363  , -0.10697533, -0.10758888, -0.10820364,
#        -0.10881957, -0.10943666, -0.11005489, -0.11067424, -0.11129468,
#        -0.1119162 , -0.11253877, -0.11316238, -0.11378701, -0.11441262,
#        -0.1150392 , -0.11566674, -0.1162952 , -0.11692457, -0.11755482,
#        -0.11818594, -0.1188179 , -0.11945068, -0.12008425, -0.12071861,
#        -0.12135372, -0.12198956, -0.12262611, -0.12326336, -0.12390126,
#        -0.12453982, -0.125179  , -0.12581878, -0.12645913, -0.12710005,
#        -0.1277415 , -0.12838346, -0.12902592, -0.12966884, -0.13031221,
#        -0.130956  , -0.13160019, -0.13224477, -0.1328897 , -0.13353497,
#        -0.13418056, -0.13482644, -0.13547258, -0.13611898, -0.1367656 ,
# ...
